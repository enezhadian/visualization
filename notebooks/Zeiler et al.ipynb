# %%
from os import path
from scipy.ndimage import imread
from IPython.display import display

from visualization import Context
from visualization.visualizers.input import ZeilerEtAlVisualizer
from visualization.visualizers import as_image

# %%
# !cd ../models && wget https://storage.googleapis.com/download.tensorflow.org/models/inception5h.zip && unzip inception5h.zip && cd ../notebooks

# %%
context = Context(path.join('..', 'models', 'tensorflow_inception_graph.pb'))

# %%
input_image_path = path.join('..', 'resources', 'eagle.jpg')
input_image = imread(input_image_path)
display(as_image(input_image))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x118E2ED68>

# %%
tensors = [
    ('maxpool0:0', 20),
    ('mixed3a:0', 188),
    ('mixed4e:0', 3)
]

zeileretal_visualizer = ZeilerEtAlVisualizer(context)
     
for t, i in tensors:
    reconstruction = zeileretal_visualizer.reconstruct_input(
        tensor_name=t,
        channel_index=i,
        input_image=input_image,
        log=False
    )
    display(as_image(reconstruction, size=[224, 224]))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x111783668>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x11B446588>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x11B50A198>
